# %%
# !nvidia-smi
# Out:
# Mon Apr  7 06:51:29 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 560.35.03              Driver Version: 560.35.03      CUDA Version: 12.6     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   63C    P0             27W /   70W |     335MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   36C    P8              9W /   70W |       3MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
! rm -rf video.mp4

# %%
import gdown

# Update with your file's specific ID
file_id = "1r0AVu38_1k2lA8unOhE0OYVDivQvbaVu"
url = f"https://drive.google.com/uc?id={file_id}"

output = "tr.mp4"
gdown.download(url, output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1r0AVu38_1k2lA8unOhE0OYVDivQvbaVu
# To: /kaggle/working/tr.mp4
# 100%|██████████| 7.04M/7.04M [00:00<00:00, 37.5MB/s]
# 'tr.mp4'

# %%
SOURCE_VIDEO_PATH = "/kaggle/working/tr.mp4"

# %%
# !pip install "ultralytics<=8.3.40"
# !pip install opencv-python
# !pip install supervision==0.3.0
# Out:
# Requirement already satisfied: ultralytics<=8.3.40 in /usr/local/lib/python3.10/dist-packages (8.3.40)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics<=8.3.40) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.40) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.0->ultralytics<=8.3.40) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.0->ultralytics<=8.3.40) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.0->ultralytics<=8.3.40) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.0->ultralytics<=8.3.40) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.0->ultralytics<=8.3.40) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.23.0->ultralytics<=8.3.40) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics<=8.3.40) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics<=8.3.40) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics<=8.3.40) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics<=8.3.40) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics<=8.3.40) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics<=8.3.40) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (2024.12.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics<=8.3.40) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics<=8.3.40) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics<=8.3.40) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics<=8.3.40) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.23.0->ultralytics<=8.3.40) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.23.0->ultralytics<=8.3.40) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.0->ultralytics<=8.3.40) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.23.0->ultralytics<=8.3.40) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.23.0->ultralytics<=8.3.40) (2024.2.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.21.2->opencv-python) (2.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.2->opencv-python) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.21.2->opencv-python) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.21.2->opencv-python) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.21.2->opencv-python) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.21.2->opencv-python) (2024.2.0)
# Requirement already satisfied: supervision==0.3.0 in /usr/local/lib/python3.10/dist-packages (0.3.0)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from supervision==0.3.0) (1.26.4)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from supervision==0.3.0) (4.10.0.84)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from supervision==0.3.0) (3.7.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->supervision==0.3.0) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->supervision==0.3.0) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->supervision==0.3.0) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->supervision==0.3.0) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->supervision==0.3.0) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.20.0->supervision==0.3.0) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->supervision==0.3.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->supervision==0.3.0) (1.17.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20.0->supervision==0.3.0) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.20.0->supervision==0.3.0) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.20.0->supervision==0.3.0) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.20.0->supervision==0.3.0) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.20.0->supervision==0.3.0) (2024.2.0)

# %%
model = YOLO('yolov8s.pt')  # Using YOLOv8 nano model (faster & lightweight)

# %%
import supervision as sv
from ultralytics import YOLO
import os
import json
import cv2
import numpy as np
from sklearn.cluster import KMeans

# -- Configs --
TARGET_VIDEO_PATH = 'output_video.mp4'
FRAME_SAVE_DIR = 'frames/'
FRAME_DATA_PATH = 'frame_data.json'
os.makedirs(FRAME_SAVE_DIR, exist_ok=True)

# Constants
SCALE_FACTOR = 0.05
FPS = 30
TARGET_WIDTH, TARGET_HEIGHT = 25, 250

# Detection polygon & perspective
SOURCE = np.array([[1252,787],[2298,803],[5039,2159],[-550,2159]])
perspective_transform = cv2.getPerspectiveTransform(
    SOURCE.astype(np.float32),
    np.array([[0,0],[TARGET_WIDTH-1,0],[TARGET_WIDTH-1,TARGET_HEIGHT-1],[0,TARGET_HEIGHT-1]],np.float32)
)

# Annotator
box_annotator = sv.BoxAnnotator(thickness=4, text_thickness=4, text_scale=2)

# Vehicle color map
color_dict = {
    "red":(255,0,0),"green":(0,255,0),"yellow":(255,255,0),
    "blue":(0,0,255),"purple":(128,0,128),"orange":(255,165,0),
    "white":(255,255,255),"black":(0,0,0),"gray":(128,128,128),
    "brown":(139,69,19),"pink":(255,192,203),"violet":(238,130,238),
    "light_red":(255,102,102),"light_green":(102,255,102),
    "light_blue":(102,102,255),"light_yellow":(255,255,102),
}

def closest_color(rgb):
    return min(color_dict, key=lambda n: np.linalg.norm(np.array(color_dict[n]) - np.array(rgb)))

def get_exact_vehicle_color(bbox, frame, k=1):
    x1,y1,x2,y2 = map(int,bbox)
    roi = frame[y1:y2, x1:x2]
    if roi.size==0: return "Unknown"
    pixels = roi.reshape(-1,3)
    kmeans = KMeans(n_clusters=k, n_init=10).fit(pixels)
    c = kmeans.cluster_centers_.astype(int)[0]
    return closest_color((c[2],c[1],c[0]))  # BGR->RGB

def is_in_target_polygon(x,y,poly):
    return cv2.pointPolygonTest(poly,(x,y),False)>=0

def calculate_speed(x,y,tid,fn):
    if tid not in VEHICLE_POSITIONS:
        VEHICLE_POSITIONS[tid]=(x,y,fn); return 0
    px,py,pf=VEHICLE_POSITIONS[tid]
    d=np.hypot(x-px,y-py); dt=(fn-pf)/FPS
    VEHICLE_POSITIONS[tid]=(x,y,fn)
    return (d/dt)*SCALE_FACTOR if dt>0 else 0

def get_vehicle_direction(x,y,tid):
    if tid in vehicle_positions:
        px,py=vehicle_positions[tid]
        return "Down" if y>py else "Up" if y<py else "Stationary"
    return "Unknown"

def get_lane(x,le,re):
    return "Left Lane" if x<le else "Right Lane" if x>re else "Middle Lane"

def detect_crossing_box(frame):
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    blur=cv2.GaussianBlur(gray,(5,5),0)
    edges=cv2.Canny(blur,50,150)
    cnts,_=cv2.findContours(edges,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    boxes=[cv2.boundingRect(c) for c in cnts if cv2.boundingRect(c)[2]>cv2.boundingRect(c)[3]*3]
    if not boxes:
        return (200,430),(600,460)
    x,y,w,h = max(boxes,key=lambda b:b[2])
    return (x,y),(x+w,y+h)

def detect_light_color(frame,box):
    x1,y1,x2,y2=map(int,box)
    roi=frame[y1:y2,x1:x2]
    if roi.size==0: return "unknown"
    hsv=cv2.cvtColor(roi,cv2.COLOR_BGR2HSV)
    r1=cv2.inRange(hsv,(0,70,50),(10,255,255))
    r2=cv2.inRange(hsv,(160,70,50),(180,255,255))
    g=cv2.inRange(hsv,(40,40,40),(80,255,255))
    y=cv2.inRange(hsv,(20,100,100),(30,255,255))
    rc, gc, yc = cv2.countNonZero(r1|r2), cv2.countNonZero(g), cv2.countNonZero(y)
    if rc>gc and rc>yc and rc>50: return "red"
    if gc>rc and gc>yc and gc>50: return "green"
    if yc>rc and yc>gc and yc>50: return "yellow"
    return "unknown"

# Init video info & counters
video_info = sv.VideoInfo.from_video_path(SOURCE_VIDEO_PATH)
left_lane,right_lane = video_info.width//3,2*(video_info.width//3)
line_y=video_info.height//2
stop_line=line_y+50

id_map,id_ctr={},1
frame_data_list=[]
vehicle_positions,vehicle_positions2={},{}
crossing_tracker={}
vehicle_crossings={'entered':0,'exited':0}
VEHICLE_POSITIONS={}
red_violators=set()

# Compute crossing box once
cap_tmp=cv2.VideoCapture(SOURCE_VIDEO_PATH)
_,first=cap_tmp.read(); cap_tmp.release()
crossing_box = detect_crossing_box(first)

# Load YOLO
model=YOLO('yolov8s.pt')

with sv.VideoSink(TARGET_VIDEO_PATH,video_info) as sink:
    for fn,result in enumerate(model.track(
        source=SOURCE_VIDEO_PATH,tracker='bytetrack.yaml',
        show=False,stream=True,agnostic_nms=True,persist=True
    )):
        frame=result.orig_img
        dets=sv.Detections.from_yolov8(result)

        # Traffic light detection
        light="unknown"
        if result.boxes.id is not None:
            for box,cls in zip(result.boxes.xyxy,result.boxes.cls):
                if model.model.names[int(cls)]=='traffic light':
                    light=detect_light_color(frame,box)
                    cv2.rectangle(frame,tuple(map(int,box[:2])),tuple(map(int,box[2:])),
                                  (0,0,255) if light=='red' else (0,255,0),2)
                    break

        # Remap tracker IDs
        if result.boxes.id is not None:
            tids=result.boxes.id.cpu().numpy().astype(int); upd=[]
            for t in tids:
                if t not in id_map: id_map[t]=id_ctr; id_ctr+=1
                upd.append(id_map[t])
            dets.tracker_id=upd

        annots=[]
        for bbox,conf,cid,tid in dets:
            tid=int(tid); bbox=list(map(float,bbox))
            cx,cy=(bbox[0]+bbox[2])/2,(bbox[1]+bbox[3])/2

            # Init if new
            if tid not in crossing_tracker:
                crossing_tracker[tid]={'crossed':False,'last_y':bbox[1],'inside':False}

            direction=get_vehicle_direction(cx,cy,tid)
            vcolor=get_exact_vehicle_color(bbox,frame)
            lane=get_lane(cx,left_lane,right_lane)
            speed=calculate_speed(cx,cy,tid,fn)

            # --- NEW VIOLATION: ENTERING the blue box while red ---
            inside = (crossing_box[0][0] <= cx <= crossing_box[1][0]
                      and crossing_box[0][1] <= cy <= crossing_box[1][1])
            violation = False
            if inside and light=='red' and tid not in red_violators:
                violation = True
                red_violators.add(tid)
            crossing_tracker[tid]['inside'] = inside

            # Entry/exit count
            last_y=crossing_tracker[tid]['last_y']
            if not crossing_tracker[tid]['crossed']:
                if cy>line_y and last_y<=line_y:
                    vehicle_crossings['entered']+=1; crossing_tracker[tid]['crossed']=True
                elif cy<line_y and last_y>=line_y:
                    vehicle_crossings['exited']+=1; crossing_tracker[tid]['crossed']=True
            crossing_tracker[tid]['last_y']=cy
            vehicle_positions2[tid]=(cx,cy)

            if is_in_target_polygon(cx,cy,SOURCE):
                lbl=f"ID:{tid}|{model.model.names[cid]} {conf:.2f}|{speed:.1f}km/h"
                frame=box_annotator.annotate(
                    scene=frame,
                    detections=sv.Detections(
                        xyxy=np.array([bbox]),confidence=np.array([conf]),
                        class_id=np.array([cid]),tracker_id=np.array([tid])
                    ),labels=[lbl]
                )
                annots.append({
                    "tracker_id":tid,"class_id":int(cid),"class_name":model.model.names[cid],
                    "direction":direction,"lane":lane,"vehicle_color":vcolor,
                    "stopped":bool(speed==0),"confidence":float(conf),"bbox":bbox,
                    "speed_kmh":speed,"red_light_violation":bool(violation)
                })

        # Draw overlays
        cv2.line(frame,(0,line_y),(video_info.width,line_y),(0,255,0),2)
        cv2.polylines(frame,[SOURCE.astype(np.int32)],True,(0,255,0),2)
        cv2.putText(frame,f"Ent:{vehicle_crossings['entered']} Ex:{vehicle_crossings['exited']}",
                    (30,50),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),2)
        cv2.putText(frame,f"Light:{light.upper()}",(30,150),
                    cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,255),2)
        # Blue crossing box
        cv2.rectangle(frame,crossing_box[0],crossing_box[1],(255,0,0),2)

        warped=cv2.warpPerspective(frame,perspective_transform,(TARGET_WIDTH,TARGET_HEIGHT))
        cv2.imwrite(f"warped_frame_{fn:04d}.jpg",warped)
        cv2.imwrite(os.path.join(FRAME_SAVE_DIR,f"frame_{fn:04d}.jpg"),
                    cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

        sink.write_frame(frame)
        frame_data_list.append({
            "frame_number":fn,"traffic_light":light,
            "congestion_level":len(dets),"detections":annots
        })

print(f"Done: entered={vehicle_crossings['entered']} exited={vehicle_crossings['exited']}")
with open(FRAME_DATA_PATH,'w') as f:
    json.dump(frame_data_list,f,indent=4)
# Out:
# video 1/1 (frame 1/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.5ms
# video 1/1 (frame 2/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 3/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 4/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 5/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 6/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 7/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 8/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 9/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 10/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 11/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 12/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.0ms
# video 1/1 (frame 13/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 14/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 15/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 16/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 17/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 18/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 19/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 20/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 21/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 22/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 23/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 24/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 25/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 26/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 27/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.0ms
# video 1/1 (frame 28/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 29/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 30/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 31/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 32/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.8ms
# video 1/1 (frame 33/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 34/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 35/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 36/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 37/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 38/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 39/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 40/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 41/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 42/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.8ms
# video 1/1 (frame 43/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 44/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 45/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 46/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 47/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 48/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 49/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 50/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 51/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 52/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 53/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 54/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 55/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 56/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 57/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 58/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.8ms
# video 1/1 (frame 59/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 60/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 61/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 62/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 63/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 64/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 65/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 66/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.8ms
# video 1/1 (frame 67/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 68/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 69/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 70/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 71/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 72/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 73/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 74/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 75/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 76/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 77/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 78/453) /kaggle/working/tr.mp4: 384x640 4 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 79/453) /kaggle/working/tr.mp4: 384x640 4 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 80/453) /kaggle/working/tr.mp4: 384x640 3 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 81/453) /kaggle/working/tr.mp4: 384x640 3 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 82/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.8ms
# video 1/1 (frame 83/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 84/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 85/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 11.0ms
# video 1/1 (frame 86/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 87/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 88/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 89/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 90/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 91/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 92/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 93/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 94/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 95/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 96/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 97/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 98/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 99/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 100/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 101/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 102/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 103/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 104/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 105/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 11.0ms
# video 1/1 (frame 106/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 107/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 108/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 109/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 110/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 111/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 112/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 113/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 11.0ms
# video 1/1 (frame 114/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 115/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 116/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 117/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 118/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 119/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 120/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 121/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 122/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 123/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 124/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 125/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 126/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 127/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 128/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 129/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 130/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 131/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 132/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 133/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 134/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 135/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 136/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 137/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 138/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 139/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 140/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 141/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 142/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 143/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 144/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 145/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 146/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 147/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 148/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 149/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 150/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 151/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 152/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 153/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 154/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 155/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 156/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 157/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 158/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 159/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 160/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 161/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 11.1ms
# video 1/1 (frame 162/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 163/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 164/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.2ms
# video 1/1 (frame 165/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 166/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 167/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 168/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 169/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 170/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 171/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 172/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 173/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 174/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 175/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.8ms
# video 1/1 (frame 176/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 177/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 178/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 12.1ms
# video 1/1 (frame 179/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 180/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 181/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 182/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 183/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 184/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 185/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 186/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 187/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 188/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 189/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 190/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 191/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 192/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 193/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 194/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 195/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 196/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 197/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 198/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 199/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 200/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 201/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 202/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 203/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 204/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 205/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 206/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 207/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 208/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 209/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 210/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 211/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 212/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 213/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 214/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 215/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 216/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 217/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 218/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 219/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 220/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 221/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 222/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 223/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 224/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 225/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 226/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 227/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 228/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 229/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.9ms
# video 1/1 (frame 230/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 231/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 232/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.9ms
# video 1/1 (frame 233/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.9ms
# video 1/1 (frame 234/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 235/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 236/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 237/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 parking meter, 10.9ms
# video 1/1 (frame 238/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 parking meter, 10.9ms
# video 1/1 (frame 239/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 240/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 parking meter, 10.8ms
# video 1/1 (frame 241/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 parking meter, 10.9ms
# video 1/1 (frame 242/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 243/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 244/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 245/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.9ms
# video 1/1 (frame 246/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 247/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 248/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.9ms
# video 1/1 (frame 249/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.9ms
# video 1/1 (frame 250/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.9ms
# video 1/1 (frame 251/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.9ms
# video 1/1 (frame 252/453) /kaggle/working/tr.mp4: 384x640 1 person, 1 traffic light, 10.8ms
# video 1/1 (frame 253/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 254/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 255/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 256/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 257/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 258/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 259/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 260/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 261/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 262/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 263/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 264/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 265/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 266/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 267/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 268/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 269/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 270/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 271/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 272/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 273/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 274/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 275/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 276/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 277/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 278/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 279/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 280/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 281/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 282/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 283/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 284/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 285/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 286/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 287/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 288/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 289/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 290/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 291/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 292/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 293/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 294/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 295/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 296/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 297/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.0ms
# video 1/1 (frame 298/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 299/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 300/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 301/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 302/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 303/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 304/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 305/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 306/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 307/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 308/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 309/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 310/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 311/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 312/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 313/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 314/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 315/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 316/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 317/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 318/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 319/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 320/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 321/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 11.0ms
# video 1/1 (frame 322/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 323/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 324/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 325/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 326/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 327/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 328/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 329/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 330/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 331/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.9ms
# video 1/1 (frame 332/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 333/453) /kaggle/working/tr.mp4: 384x640 1 traffic light, 10.8ms
# video 1/1 (frame 334/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 335/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 336/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 337/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 338/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 339/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 340/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 341/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 342/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 343/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 344/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 345/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.2ms
# video 1/1 (frame 346/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 347/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 348/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 349/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.1ms
# video 1/1 (frame 350/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 351/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 352/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 353/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 354/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 355/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 356/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 357/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.0ms
# video 1/1 (frame 358/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 359/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 360/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 361/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 362/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 363/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 364/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 365/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 366/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 367/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 368/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 369/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 370/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 371/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 372/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 373/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 374/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 375/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 376/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 377/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 378/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 379/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 380/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 381/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 382/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 383/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 384/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 385/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 386/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 387/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 11.0ms
# video 1/1 (frame 388/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 389/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 390/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 391/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 392/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 393/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 394/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 395/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 396/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 397/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 398/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 399/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 400/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 401/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 402/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 403/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 404/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 405/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 406/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 407/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 408/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 409/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 410/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 411/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 412/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 413/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 414/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 415/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 416/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.8ms
# video 1/1 (frame 417/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 418/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 11.0ms
# video 1/1 (frame 419/453) /kaggle/working/tr.mp4: 384x640 2 cars, 1 traffic light, 10.9ms
# video 1/1 (frame 420/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 421/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 422/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 423/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 424/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 425/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 426/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 427/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 428/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 429/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 430/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 431/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 432/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 433/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 434/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 435/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 436/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 437/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 438/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 439/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 440/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 441/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 442/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 443/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 444/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 445/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 446/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 447/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 448/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 449/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.8ms
# video 1/1 (frame 450/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 451/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 452/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# video 1/1 (frame 453/453) /kaggle/working/tr.mp4: 384x640 1 car, 1 traffic light, 10.9ms
# Speed: 2.2ms preprocess, 10.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Done: entered=1 exited=3
